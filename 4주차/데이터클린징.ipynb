# %% [markdown]
# ### 1. 데이터 클린징

# %% [markdown]
# ### 2. 결측데이터

# %%
import pandas as pd 
#파일경로를 찾고 변수 file_path에 저장
file_path= 'bicycle.csv'

#read csv()함수로 데이터프레임 변환 #한글이 들어가서 cp949를 쓴다.
df = pd.read_csv(file_path, encoding='CP949')
df
# Out:
#          자전거번호              대여일시  대여소번호               대여소명  대여거치대  \
# 0    SPB-23220   2019-11-01 8:48    646  장한평역 1번출구 (국민은행앞)    3.0
# 1    SPB-16216   2019-11-04 8:38    646  장한평역 1번출구 (국민은행앞)    2.0
# 2    SPB-21097   2019-11-04 8:46    646  장한평역 1번출구 (국민은행앞)    1.0
# 3    SPB-22292   2019-11-05 8:34    646  장한평역 1번출구 (국민은행앞)    1.0
# 4    SPB-07935  2019-11-05 12:29    512        뚝섬역 1번 출구 옆   11.0
# ..         ...               ...    ...                ...    ...
# 415  SPB-12116   2019-11-15 4:22    112            극동방송국 앞    5.0
# 416  SPB-17768   2019-11-15 9:31    103         망원역 2번출구 앞   14.0
# 417  SPB-18841  2019-11-15 20:40    113       홍대입구역 2번출구 앞   24.0
# 418  SPB-24467  2019-11-15 21:55    152         마포구민체육센터 앞   18.0
# 419  SPB-17570  2019-11-15 22:16    391              정동길입구    7.0
#
#                  반납일시  반납대여소번호       반납대여소명  반납거치대  이용시간    이용거리
# 0     2019-11-01 9:01        3         중랑센터    7.0  12.0  1100.0
# ...

# %% [markdown]
# #### 결측데이터 확인

# %%
# 결측데이터 확인 # nan이 있는 건 결측데이터로 간주해 true로 나온다.
df.isnull( )
# Out:
#      자전거번호   대여일시  대여소번호   대여소명  대여거치대   반납일시  반납대여소번호  반납대여소명  반납거치대   이용시간  \
# 0    False  False  False  False  False  False    False   False  False  False
# 1    False  False  False  False  False  False    False   False  False  False
# 2    False  False  False  False  False  False    False   False  False  False
# 3    False  False  False  False  False  False    False   False   True  False
# 4    False  False  False  False  False  False    False   False  False  False
# ..     ...    ...    ...    ...    ...    ...      ...     ...    ...    ...
# 415  False  False  False  False  False  False    False   False  False  False
# 416  False  False  False  False  False  False    False   False   True  False
# 417  False  False  False  False  False  False    False   False  False  False
# 418  False  False  False  False  False  False    False   False  False  False
# 419  False  False  False  False  False  False    False   False  False  False
#
#       이용거리
# 0    False
# 1    False
# ...

# %%
df.notnull()
# Out:
# 자전거번호      420
# 대여일시       420
# 대여소번호      420
# 대여소명       420
# 대여거치대      396
# 반납일시       420
# 반납대여소번호    420
# 반납대여소명     420
# 반납거치대      409
# 이용시간       405
# 이용거리       404
# dtype: int64

# %%
# 결측값 개수
df.isnull().sum()

# %%
# 행단위 결측값 개수
df.isnull().sum(axis=1)
# Out:
# 0      0
# 1      0
# 2      1
# 3      1
# 4      0
#       ..
# 415    0
# 416    2
# 417    0
# 418    0
# 419    0
# Length: 420, dtype: int64

# %%
# 행단위 실제값 개수
df.notnull().sum(1)
# Out:
# 0      11
# 1      11
# 2      10
# 3      10
# 4      11
#        ..
# 415    11
# 416     9
# 417    11
# 418    11
# 419    11
# Length: 420, dtype: int64

# %% [markdown]
# #### 결측데이터 제거

# %%
#결측치가 있는 전체 행 제거
df_drop_allrow = df.dropna(axis=0)
df_drop_allrow
# Out:
#          자전거번호              대여일시  대여소번호               대여소명  대여거치대  \
# 0    SPB-23220   2019-11-01 8:48    646  장한평역 1번출구 (국민은행앞)    3.0
# 1    SPB-16216   2019-11-04 8:38    646  장한평역 1번출구 (국민은행앞)    2.0
# 4    SPB-07935  2019-11-05 12:29    512        뚝섬역 1번 출구 옆   11.0
# 5    SPB-18401   2019-11-06 8:52    646  장한평역 1번출구 (국민은행앞)    1.0
# 6    SPB-18350   2019-11-06 8:35    646  장한평역 1번출구 (국민은행앞)    1.0
# ..         ...               ...    ...                ...    ...
# 414  SPB-24515   2019-11-15 3:58    112            극동방송국 앞    1.0
# 415  SPB-12116   2019-11-15 4:22    112            극동방송국 앞    5.0
# 417  SPB-18841  2019-11-15 20:40    113       홍대입구역 2번출구 앞   24.0
# 418  SPB-24467  2019-11-15 21:55    152         마포구민체육센터 앞   18.0
# 419  SPB-17570  2019-11-15 22:16    391              정동길입구    7.0
#
#                  반납일시  반납대여소번호       반납대여소명  반납거치대  이용시간    이용거리
# 0     2019-11-01 9:01        3         중랑센터    7.0  12.0  1100.0
# ...

# %%
#결측치가 있는 전체 열 제거
df_drop_allcolumn = df.dropna(axis=1)
df_drop_allcolumn
# Out:
#          자전거번호              대여일시  대여소번호               대여소명              반납일시  \
# 0    SPB-23220   2019-11-01 8:48    646  장한평역 1번출구 (국민은행앞)   2019-11-01 9:01
# 1    SPB-16216   2019-11-04 8:38    646  장한평역 1번출구 (국민은행앞)   2019-11-04 8:56
# 2    SPB-21097   2019-11-04 8:46    646  장한평역 1번출구 (국민은행앞)   2019-11-04 8:57
# 3    SPB-22292   2019-11-05 8:34    646  장한평역 1번출구 (국민은행앞)   2019-11-05 8:45
# 4    SPB-07935  2019-11-05 12:29    512        뚝섬역 1번 출구 옆  2019-11-05 12:39
# ..         ...               ...    ...                ...               ...
# 415  SPB-12116   2019-11-15 4:22    112            극동방송국 앞   2019-11-15 4:33
# 416  SPB-17768   2019-11-15 9:31    103         망원역 2번출구 앞   2019-11-15 9:37
# 417  SPB-18841  2019-11-15 20:40    113       홍대입구역 2번출구 앞  2019-11-15 20:53
# 418  SPB-24467  2019-11-15 21:55    152         마포구민체육센터 앞  2019-11-15 22:05
# 419  SPB-17570  2019-11-15 22:16    391              정동길입구  2019-11-15 23:04
#
#      반납대여소번호       반납대여소명
# ...

# %%
#특정 행 또는 열 결측치 제거, 대여소번호 컬럼 제거(비교확인)
df[['대여소번호']].dropna() # 결측치가 하나도 없으니까 그냥 이렇게 나오는 거다.
# Out:
#      대여소번호
# 0      646
# 1      646
# 2      646
# 3      646
# 4      512
# ..     ...
# 415    112
# 416    103
# 417    113
# 418    152
# 419    391
#
# [420 rows x 1 columns]

# %%
# 하단 df.dropna(axis=0)와 동일 
df[['대여소번호','대여거치대','이용시간']].dropna()
# Out:
#      대여소번호  대여거치대  이용시간
# 0      646    3.0  12.0
# 1      646    2.0   7.0
# 2      646    1.0  10.0
# 3      646    1.0  10.0
# 4      512   11.0  10.0
# ..     ...    ...   ...
# 415    112    5.0  11.0
# 416    103   14.0   5.0
# 417    113   24.0  12.0
# 418    152   18.0  10.0
# 419    391    7.0  48.0
#
# [382 rows x 3 columns]

# %%
df1 = df[['대여소번호','대여거치대','이용시간']].dropna(axis=0)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 382 entries, 0 to 419
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대여소번호   382 non-null    int64
#  1   대여거치대   382 non-null    float64
#  2   이용시간    382 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 11.9 KB

# %%
df[['대여소번호','대여거치대','이용시간']].dropna(axis=1)
# Out:
#      대여소번호
# 0      646
# 1      646
# 2      646
# 3      646
# 4      512
# ..     ...
# 415    112
# 416    103
# 417    113
# 418    152
# 419    391
#
# [420 rows x 1 columns]

# %% [markdown]
# #### 결측데이터 대체

# %%
#결측값을 특정 값(0)으로 대체
df_1 = df['이용시간'].fillna(0) # 이렇게 나오면 모르니까 이용시간을 뺴고 df.fillna(0) 이렇게 하면 알아 볼 수 있게 보인다.
df_1
# Out:
#          자전거번호              대여일시  대여소번호               대여소명  대여거치대  \
# 0    SPB-23220   2019-11-01 8:48    646  장한평역 1번출구 (국민은행앞)    3.0
# 1    SPB-16216   2019-11-04 8:38    646  장한평역 1번출구 (국민은행앞)    2.0
# 2    SPB-21097   2019-11-04 8:46    646  장한평역 1번출구 (국민은행앞)    1.0
# 3    SPB-22292   2019-11-05 8:34    646  장한평역 1번출구 (국민은행앞)    1.0
# 4    SPB-07935  2019-11-05 12:29    512        뚝섬역 1번 출구 옆   11.0
# ..         ...               ...    ...                ...    ...
# 415  SPB-12116   2019-11-15 4:22    112            극동방송국 앞    5.0
# 416  SPB-17768   2019-11-15 9:31    103         망원역 2번출구 앞   14.0
# 417  SPB-18841  2019-11-15 20:40    113       홍대입구역 2번출구 앞   24.0
# 418  SPB-24467  2019-11-15 21:55    152         마포구민체육센터 앞   18.0
# 419  SPB-17570  2019-11-15 22:16    391              정동길입구    7.0
#
#                  반납일시  반납대여소번호       반납대여소명  반납거치대  이용시간    이용거리
# 0     2019-11-01 9:01        3         중랑센터    7.0  12.0  1100.0
# ...

# %%
#특정 컬럼 결측값을 특정 값(0)으로 대체 
df_2 = df.대여소번호.fillna(0)
df_2

# %%
#결측값을 문자열('missing')로 대체
df_3 = df.fillna('missing')
df_3
# Out:
#          자전거번호              대여일시  대여소번호               대여소명 대여거치대  \
# 0    SPB-23220   2019-11-01 8:48    646  장한평역 1번출구 (국민은행앞)   3.0
# 1    SPB-16216   2019-11-04 8:38    646  장한평역 1번출구 (국민은행앞)   2.0
# 2    SPB-21097   2019-11-04 8:46    646  장한평역 1번출구 (국민은행앞)   1.0
# 3    SPB-22292   2019-11-05 8:34    646  장한평역 1번출구 (국민은행앞)   1.0
# 4    SPB-07935  2019-11-05 12:29    512        뚝섬역 1번 출구 옆  11.0
# ..         ...               ...    ...                ...   ...
# 415  SPB-12116   2019-11-15 4:22    112            극동방송국 앞   5.0
# 416  SPB-17768   2019-11-15 9:31    103         망원역 2번출구 앞  14.0
# 417  SPB-18841  2019-11-15 20:40    113       홍대입구역 2번출구 앞  24.0
# 418  SPB-24467  2019-11-15 21:55    152         마포구민체육센터 앞  18.0
# 419  SPB-17570  2019-11-15 22:16    391              정동길입구   7.0
#
#                  반납일시  반납대여소번호       반납대여소명    반납거치대  이용시간     이용거리
# 0     2019-11-01 9:01        3         중랑센터      7.0  12.0   1100.0
# ...

# %%
# 각 칼럼의 평균을 구해서 대응하는 칼럼의 결측값을 대체하는 방법으로 가장 많이 사용된다. 
df_4=df['이용시간'].fillna(df['이용시간'].mean())
df_4
# Out:
# 0      12.0
# 1       7.0
# 2      10.0
# 3      10.0
# 4      10.0
#        ...
# 415    11.0
# 416     5.0
# 417    12.0
# 418    10.0
# 419    48.0
# Name: 이용시간, Length: 420, dtype: float64

# %%
# 특정항목 평균 구하기(이용거리평균)
df_5= df['이용거리'].mean()
df_5

# %%
#특정항목 평균으로 대체 
df_6 = df['이용거리'].fillna(df['이용거리'].mean())
df_6
# Out:
# 0      1100.000000
# 1      1420.000000
# 2      2679.678218
# 3      1380.000000
# 4      1650.000000
#           ...
# 415    2200.000000
# 416    2679.678218
# 417    2280.000000
# 418    1180.000000
# 419    8100.000000
# Name: 이용거리, Length: 420, dtype: float64

# %%
##특정항목 평균으로 대체 
df_7 = df.이용거리.fillna(df['이용거리'].mean())
df_7
# Out:
# 0      1100.000000
# 1      1420.000000
# 2      2679.678218
# 3      1380.000000
# 4      1650.000000
#           ...
# 415    2200.000000
# 416    2679.678218
# 417    2280.000000
# 418    1180.000000
# 419    8100.000000
# Name: 이용거리, Length: 420, dtype: float64

# %% [markdown]
# ### 3. 이상데이터

# %%
import pandas as pd 
#파일경로를 찾고 변수 file_path에 저장
file_path= 'bicycle.csv'

#read csv()함수로 데이터프레임 변환 
df = pd.read_csv(file_path, encoding='CP949')
df
# Out:
#          자전거번호              대여일시  대여소번호               대여소명  대여거치대  \
# 0    SPB-23220   2019-11-01 8:48    646  장한평역 1번출구 (국민은행앞)    3.0
# 1    SPB-16216   2019-11-04 8:38    646  장한평역 1번출구 (국민은행앞)    2.0
# 2    SPB-21097   2019-11-04 8:46    646  장한평역 1번출구 (국민은행앞)    1.0
# 3    SPB-22292   2019-11-05 8:34    646  장한평역 1번출구 (국민은행앞)    1.0
# 4    SPB-07935  2019-11-05 12:29    512        뚝섬역 1번 출구 옆   11.0
# ..         ...               ...    ...                ...    ...
# 415  SPB-12116   2019-11-15 4:22    112            극동방송국 앞    5.0
# 416  SPB-17768   2019-11-15 9:31    103         망원역 2번출구 앞   14.0
# 417  SPB-18841  2019-11-15 20:40    113       홍대입구역 2번출구 앞   24.0
# 418  SPB-24467  2019-11-15 21:55    152         마포구민체육센터 앞   18.0
# 419  SPB-17570  2019-11-15 22:16    391              정동길입구    7.0
#
#                  반납일시  반납대여소번호       반납대여소명  반납거치대  이용시간    이용거리
# 0     2019-11-01 9:01        3         중랑센터    7.0  12.0  1100.0
# ...

# %%
# 이상값이 있는 1번째 행 제거, 이용시간 한 개라 시리즈다.
a = df['이용시간'].dropna(axis=0)
print(a.info())
df.info() # df는 그대로 있다는 것을 알 수 있다.
# Out:
# <class 'pandas.core.series.Series'>
# Index: 405 entries, 0 to 419
# Series name: 이용시간
# Non-Null Count  Dtype
# --------------  -----
# 405 non-null    float64
# dtypes: float64(1)
# memory usage: 6.3 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   자전거번호    420 non-null    object
#  1   대여일시     420 non-null    object
#  2   대여소번호    420 non-null    int64
#  3   대여소명     420 non-null    object
#  4   대여거치대    396 non-null    float64
#  5   반납일시     420 non-null    object
#  6   반납대여소번호  420 non-null    int64
#  7   반납대여소명   420 non-null    object
#  8   반납거치대    409 non-null    float64
#  9   이용시간     405 non-null    float64
#  10  이용거리     404 non-null    float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 36.2+ KB

# %%
import matplotlib as mpl       #맷플롭립
import matplotlib.pylab as plt   #맷플롭립

plt.boxplot(a)
plt.show()

# %% [markdown]
# ### 4. 중복데이터

# %%
import pandas as pd 
#파일경로를 찾고 변수 file_path에 저장
file_path= 'bicycle.csv'
#read csv()함수로 데이터프레임 변환 

df = pd.read_csv(file_path,encoding='CP949')
df
# Out:
#          자전거번호              대여일시  대여소번호               대여소명  대여거치대  \
# 0    SPB-23220   2019-11-01 8:48    646  장한평역 1번출구 (국민은행앞)    3.0
# 1    SPB-16216   2019-11-04 8:38    646  장한평역 1번출구 (국민은행앞)    2.0
# 2    SPB-21097   2019-11-04 8:46    646  장한평역 1번출구 (국민은행앞)    1.0
# 3    SPB-22292   2019-11-05 8:34    646  장한평역 1번출구 (국민은행앞)    1.0
# 4    SPB-07935  2019-11-05 12:29    512        뚝섬역 1번 출구 옆   11.0
# ..         ...               ...    ...                ...    ...
# 415  SPB-12116   2019-11-15 4:22    112            극동방송국 앞    5.0
# 416  SPB-17768   2019-11-15 9:31    103         망원역 2번출구 앞   14.0
# 417  SPB-18841  2019-11-15 20:40    113       홍대입구역 2번출구 앞   24.0
# 418  SPB-24467  2019-11-15 21:55    152         마포구민체육센터 앞   18.0
# 419  SPB-17570  2019-11-15 22:16    391              정동길입구    7.0
#
#                  반납일시  반납대여소번호       반납대여소명  반납거치대  이용시간    이용거리
# 0     2019-11-01 9:01        3         중랑센터    7.0  12.0  1100.0
# ...

# %% [markdown]
# #### 중복데이터 확인

# %%
# duplicated() 메소드로 중복 데이터 찾기
#dataFrame.duplicated()는 True, False 의 boolean 형태의 Series반환

df.duplicated(['이용거리'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 415    False
# 416     True
# 417     True
# 418     True
# 419    False
# Length: 420, dtype: bool

# %%
df.duplicated(['이용거리','이용시간'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 415    False
# 416    False
# 417    False
# 418    False
# 419    False
# Length: 420, dtype: bool

# %% [markdown]
# #### 중복데이터 시작과 끝 확인

# %%
# keep='first'가 default 이며, 중복값이 있으면 첫번째 값을 duplicated 여부를 False로 반환 나머지 중복값에 대해서는 True를 반환
df.duplicated(['이용거리'],keep='first') #기본값
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 415    False
# 416     True
# 417     True
# 418     True
# 419    False
# Length: 420, dtype: bool

# %%
# keep='last'는 중복값이 있으면 첫번째 값을 duplicated 여부를 True로 반환 나머지 중복값에 대해서는 False를 반환
df.duplicated(['이용거리'],keep='last')

# %%
# keep=False는 처음이나 끝값인지 여부는 고려를 안하고 중복이면 무조건 True를 반환
df.duplicated(['이용거리'],keep=False)

# %% [markdown]
# #### 중복 제거: 유일한 1개 키만 남기고 나머지

# %%
# drop_duplicates()는 중복값을 keep='first', 'last', False argument에 따라 유일한 1개의 key값만 남기고 나머지는 중복 제거

df.drop_duplicates(['이용거리'],keep='first')
# Out:
#          자전거번호              대여일시  대여소번호               대여소명  대여거치대  \
# 0    SPB-23220   2019-11-01 8:48    646  장한평역 1번출구 (국민은행앞)    3.0
# 1    SPB-16216   2019-11-04 8:38    646  장한평역 1번출구 (국민은행앞)    2.0
# 2    SPB-21097   2019-11-04 8:46    646  장한평역 1번출구 (국민은행앞)    1.0
# 3    SPB-22292   2019-11-05 8:34    646  장한평역 1번출구 (국민은행앞)    1.0
# 4    SPB-07935  2019-11-05 12:29    512        뚝섬역 1번 출구 옆   11.0
# ..         ...               ...    ...                ...    ...
# 410  SPB-18614  2019-11-14 23:07    391              정동길입구    5.0
# 413  SPB-25161   2019-11-15 3:13    106         합정역 7번출구 앞    6.0
# 414  SPB-24515   2019-11-15 3:58    112            극동방송국 앞    1.0
# 415  SPB-12116   2019-11-15 4:22    112            극동방송국 앞    5.0
# 419  SPB-17570  2019-11-15 22:16    391              정동길입구    7.0
#
#                  반납일시  반납대여소번호       반납대여소명  반납거치대  이용시간    이용거리
# 0     2019-11-01 9:01        3         중랑센터    7.0  12.0  1100.0
# ...

# %%
df.drop_duplicates(['이용거리'], keep='last')
# Out:
#          자전거번호              대여일시  대여소번호               대여소명  대여거치대  \
# 4    SPB-07935  2019-11-05 12:29    512        뚝섬역 1번 출구 옆   11.0
# 6    SPB-18350   2019-11-06 8:35    646  장한평역 1번출구 (국민은행앞)    1.0
# 10   SPB-10000   2019-11-12 8:35    646  장한평역 1번출구 (국민은행앞)    8.0
# 15   SPB-13973   2019-11-15 8:42    646  장한평역 1번출구 (국민은행앞)    1.0
# 19   SPB-23497   2019-11-21 8:50    646  장한평역 1번출구 (국민은행앞)    2.0
# ..         ...               ...    ...                ...    ...
# 415  SPB-12116   2019-11-15 4:22    112            극동방송국 앞    5.0
# 416  SPB-17768   2019-11-15 9:31    103         망원역 2번출구 앞   14.0
# 417  SPB-18841  2019-11-15 20:40    113       홍대입구역 2번출구 앞   24.0
# 418  SPB-24467  2019-11-15 21:55    152         마포구민체육센터 앞   18.0
# 419  SPB-17570  2019-11-15 22:16    391              정동길입구    7.0
#
#                  반납일시  반납대여소번호       반납대여소명  반납거치대  이용시간    이용거리
# 4    2019-11-05 12:39        3         중랑센터    7.0  10.0  1650.0
# ...

# %%
df.drop_duplicates(['이용거리'], keep=False)
